# %%
import datetime
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import glob
import os



import warnings

warnings.filterwarnings("ignore", category=FutureWarning)
pd.set_option('display.max_columns', None)

# %%
df_list = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0,  delimiter='|', on_bad_lines='skip')
    
    base = os.path.basename(filename)  #
    transaction_id = int(base.split('_')[-1].split('.')[0]) 
    df['transaction_id'] = transaction_id  
    
    df_list.append(df)
    

df_list = [df.dropna(axis=1, how='all') for df in df_list]

transactions= pd.concat(df_list, axis=0, ignore_index=True)

# %%
transactions.shape
# Out:
# (4260904, 11)

# %%
transactions.head(1)
# Out:
#           cc_num      acct_num                         trans_num   unix_time  \
# 0  4218196001337  888022315787  91ab12e73ef38206e1121e9648d2408d  1558719550
#
#         category    amt  is_fraud        merchant  merch_lat  merch_long  \
# 0  gas_transport  69.12         0  Phillips Group  39.491416  -75.588522
#
#    transaction_id
# 0               0

# %%
customers.head(1)
# Out:
#            ssn         cc_num     first     last gender                street  \
# 0  115-04-4507  4218196001337  Jonathan  Johnson      M  863 Lawrence Valleys
#
#      city state    zip      lat     long  city_pop                    job  \
# 0  Ambler    PA  19002  40.1809 -75.2156     32412  Accounting technician
#
#           dob      acct_num
# 0  1959-10-03  888022315787

# %% [markdown]
# df union

# %%
df_final = transactions.merge(customers.drop('acct_num', axis=1), on='cc_num')

# %%
df_final.head(2)
# Out:
#           cc_num      acct_num                         trans_num   unix_time  \
# 0  4218196001337  888022315787  91ab12e73ef38206e1121e9648d2408d  1558719550
# 1  4218196001337  888022315787  071553d533a6822a4431c354c434ddcb  1569425519
#
#         category    amt  is_fraud        merchant  merch_lat  merch_long  \
# 0  gas_transport  69.12         0  Phillips Group  39.491416  -75.588522
# 1    grocery_pos  68.11         0      Tucker Ltd  40.890319  -75.573359
#
#    transaction_id          ssn     first     last gender  \
# 0               0  115-04-4507  Jonathan  Johnson      M
# 1               0  115-04-4507  Jonathan  Johnson      M
#
#                  street    city state    zip      lat     long  city_pop  \
# 0  863 Lawrence Valleys  Ambler    PA  19002  40.1809 -75.2156     32412
# 1  863 Lawrence Valleys  Ambler    PA  19002  40.1809 -75.2156     32412
#
#                      job         dob
# 0  Accounting technician  1959-10-03
# 1  Accounting technician  1959-10-03

# %%
df_final.shape
# Out:
# (4260904, 24)

# %% [markdown]
# ## EDA

# %%
sns.histplot(data=df_final, y=df.unix_time)
# Out:
# <Axes: xlabel='Count', ylabel='unix_time'>

# %%
df_final['unix_time'] = pd.to_datetime(df_final['unix_time'], unit='s')

# %%
date = '2022-06-01'

# %%
df = df_final[(df_final['unix_time'] >= '2022-06-01')].reset_index(drop=True).copy(deep = True)

# %%
df.head()
# Out:
#           cc_num      acct_num                         trans_num  \
# 0  4218196001337  888022315787  b45d68c71229562b6fd243d91b97a742
# 1  4218196001337  888022315787  0f0e9a35ea0161db8140010bb1e92b97
# 2  4218196001337  888022315787  c6a4b5c5831983cc8fd08200e31e7618
# 3  4218196001337  888022315787  202f01c021fe6ec0e7d0b3d67356844c
# 4  4218196001337  888022315787  f3c46d60210ff65afe002f36f5085726
#
#             unix_time       category     amt  is_fraud  \
# 0 2022-10-25 12:12:02  personal_care   97.33         0
# 1 2022-11-15 03:54:44  personal_care  131.27         0
# 2 2022-12-24 02:32:20         travel   65.00         0
# 3 2022-12-06 05:51:09         travel   98.60         0
# 4 2022-08-27 06:16:32  personal_care   57.98         0
#
#                   merchant  merch_lat  merch_long  transaction_id  \
# 0           Townsend-Moore  40.852780  -75.820295               0
# 1               Miller Inc  40.959699  -75.655453               0
# 2               Hays-Bowen  40.394782  -74.705600               0
# 3              Sherman Inc  41.034767  -75.910049               0
# 4  Morgan, Hunter and Wood  39.833264  -74.310873               0
#
#            ssn     first     last gender                street    city state  \
# 0  115-04-4507  Jonathan  Johnson      M  863 Lawrence Valleys  Ambler    PA
# 1  115-04-4507  Jonathan  Johnson      M  863 Lawrence Valleys  Ambler    PA
# 2  115-04-4507  Jonathan  Johnson      M  863 Lawrence Valleys  Ambler    PA
# 3  115-04-4507  Jonathan  Johnson      M  863 Lawrence Valleys  Ambler    PA
# 4  115-04-4507  Jonathan  Johnson      M  863 Lawrence Valleys  Ambler    PA
#
#      zip      lat     long  city_pop                    job         dob
# 0  19002  40.1809 -75.2156     32412  Accounting technician  1959-10-03
# 1  19002  40.1809 -75.2156     32412  Accounting technician  1959-10-03
# 2  19002  40.1809 -75.2156     32412  Accounting technician  1959-10-03
# 3  19002  40.1809 -75.2156     32412  Accounting technician  1959-10-03
# 4  19002  40.1809 -75.2156     32412  Accounting technician  1959-10-03

# %%
df.to_csv('final.csv', sep=',')

# %%
sns.histplot(data=df, y=df.unix_time)
# Out:
# <Axes: xlabel='Count', ylabel='unix_time'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1117411 entries, 0 to 1117410
# Data columns (total 24 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   cc_num          1117411 non-null  int64
#  1   acct_num        1117411 non-null  int64
#  2   trans_num       1117411 non-null  object
#  3   unix_time       1117411 non-null  datetime64[ns]
#  4   category        1117411 non-null  object
#  5   amt             1117411 non-null  float64
#  6   is_fraud        1117411 non-null  int64
#  7   merchant        1117411 non-null  object
#  8   merch_lat       1117411 non-null  float64
#  9   merch_long      1117411 non-null  float64
#  10  transaction_id  1117411 non-null  int64
#  11  ssn             1117411 non-null  object
#  12  first           1117411 non-null  object
#  13  last            1117411 non-null  object
#  14  gender          1117411 non-null  object
#  15  street          1117411 non-null  object
#  16  city            1117411 non-null  object
#  17  state           1117411 non-null  object
#  18  zip             1117411 non-null  int64
#  19  lat             1117411 non-null  float64
#  20  long            1117411 non-null  float64
#  21  city_pop        1117411 non-null  int64
#  22  job             1117411 non-null  object
#  23  dob             1117411 non-null  object
# dtypes: datetime64[ns](1), float64(5), int64(6), object(12)
# memory usage: 204.6+ MB

# %%
df.isnull().sum()
# Out:
# cc_num            0
# acct_num          0
# trans_num         0
# unix_time         0
# category          0
# amt               0
# is_fraud          0
# merchant          0
# merch_lat         0
# merch_long        0
# transaction_id    0
# ssn               0
# first             0
# last              0
# gender            0
# street            0
# city              0
# state             0
# zip               0
# lat               0
# long              0
# city_pop          0
# job               0
# dob               0
# dtype: int64

# %%
df['dob'] = pd.to_datetime(df['dob'])

# %%
df['age'] = df['dob'].apply(lambda x: datetime.datetime.now().year - x.year - ((datetime.datetime.now().month, datetime.datetime.now().day) < (x.month, x.day)))

# %%
occupations = {
    'Accounting/Finance': ['Accountant, Chartered', 'Accountant, Chartered Management', 'Chartered Accountant', 'Chief Financial Officer', 'Financial Trader', 'Investment Banker, Operational', 'Financial Risk Analyst', 'Pensions Consultant', 'Tax Adviser'],
    'Education/Teaching': ['Lecturer, Further Education', 'Teacher, Adult Education', 'Teacher, Early Years/Pre', 'Teacher, English as a Foreign Language', 'Teacher, Music', 'Teacher, Primary School', 'Teacher, Secondary School', 'Teacher, Special Educational Needs', 'Teacher, Secondary School'],
    'Healthcare/Medical': ['Acupuncturist', 'Anaesthetist', 'Chiropodist', 'Dentist', 'Dietitian', 'Doctor, Hospital', 'Haematologist', 'Midwife', 'Neurosurgeon', 'Nurse, Adult', 'Nurse, Children\'s', 'Nurse, Learning Disability', 'Nurse, Mental Health', 'Occupational Therapist', 'Oncologist', 'Ophthalmologist', 'Orthoptist', 'Paediatric Nurse', 'Paramedic', 'Pathologist', 'Physiotherapist', 'Psychiatrist', 'Radiation Protection Practitioner', 'Radiographer, Diagnostic', 'Radiographer, Therapeutic', 'Surgeon', 'Clinical Scientist, Histocompatibility and Immunogenetics', 'Clinical Biochemist', 'Clinical Cytogeneticist', 'Clinical Embryologist', 'Clinical Molecular Geneticist', 'Clinical Psychologist', 'Clinical Research Associate', 'Mental Health Nurse', 'Physiological Scientist', 'Public Health Specialist', 'Medical Laboratory Scientific Officer'],
    'Information Technology/Computer Science': ['Applications Developer', 'Data Scientist', 'IT Consultant', 'IT Sales Professional', 'Network Engineer', 'Software Engineer', 'Systems Analyst', 'Systems Developer', 'Technical Author'],
    'Engineering/Technical': ['Aeronautical Engineer', 'Agricultural Engineer', 'Automotive Engineer', 'Chemical Engineer', 'Civil Engineer', 'Drilling Engineer', 'Electrical Engineer', 'Electronics Engineer', 'Energy Engineer', 'Environmental Engineer', 'Geologist, Engineering', 'Geographical Information Systems Officer', 'Hydrogeologist', 'Materials Engineer', 'Mechanical Engineer', 'Mining Engineer', 'Petroleum Engineer', 'Structural Engineer', 'Water Engineer'],
    'Legal': ['Barrister\'s Clerk', 'Legal Executive', 'Lawyer', 'Legal Secretary', 'Solicitor'],
    'Creative/Artistic': ['Actor', 'Animator', 'Art Gallery Manager', 'Art Therapist', 'Artist', 'Ceramics Designer', 'Composer', 'Conservator, Furniture', 'Copywriter, Advertising', 'Designer, Exhibition/Display', 'Designer, Fashion/Clothing', 'Designer, Furniture', 'Designer, Graphic', 'Designer, Industrial/Product', 'Designer, Interior/Spatial', 'Designer, Jewellery', 'Designer, Multimedia', 'Designer, Textile', 'Designer, Television/Film Set', 'Director, Theatre', 'Editorial Assistant', 'Fashion Designer', 'Fine Artist', 'Illustrator', 'Interior and Spatial Designer', 'Jewellery Designer', 'Make-Up Artist', 'Musician', 'Playwright', 'Poet', 'Printmaker', 'Proofreader', 'Set Designer', 'Stage Manager', 'Theatre Director', 'Visual Merchandiser', 'Writer'],
    'Business/Management/Administration': ['Administrator', 'Administrator, Arts', 'Administrator, Charities/Voluntary Organizations', 'Administrator, Civil Service', 'Administrator, Education', 'Advertising Account Executive', 'Advertising Account Planner', 'Advertising Art Director', 'Advertising Copywriter', 'Applications Developer', 'Business Analyst', 'Business Development Manager', 'Business Intelligence Analyst', 'Business Manager', 'Cabin Crew', 'Call Centre Manager', 'Catering Manager', 'Chief Executive Officer', 'Chief Marketing Officer', 'Chief of Staff', 'Company Secretary', 'Compliance Officer', 'Contractor', 'Customer Service Manager', 'Data Processing Manager', 'Facilities Manager', 'Health Service Manager', 'Hotel Manager', 'Housing Manager/Officer', 'Human Resources Officer', 'Information Officer', 'Insurance Account Manager', 'Insurance Broker', 'Intelligence Analyst', 'Interpreter', 'IT Trainer', 'Land/Property Manager', 'Landlord/Tenant Manager', 'Lobbyist', 'Loss Adjuster, Chartered', 'Management Consultant', 'Market Researcher', 'Marketing Executive', 'Office Manager', 'Operations Manager', 'Product Manager', 'Project Manager', 'Purchasing Manager', 'Quality Manager', 'Recruitment Consultant', 'Relationship Manager', 'Sales Executive', 'Sales Promotion Account Executive', 'Sales Professional, IT', 'Sales Support Administrator', 'Stockbroker', 'Supply Chain Manager', 'Systems Developer', 'Tax Adviser', 'Technical Sales Engineer', 'Tour Manager', 'Tourism Officer', 'Trade Union Research Officer', 'Translator', 'Warehouse Manager'],
    'Research/Science': ['Archaeologist', 'Astronomer', 'Biologist', 'Botanist', 'Chemist', 'Clinical Research Associate', 'Data Scientist', 'Ecologist', 'Environmental Consultant', 'Geneticist', 'Marine Scientist', 'Mathematician', 'Meteorologist', 'Microbiologist', 'Oceanographer', 'Physicist', 'Research Scientist', 'Scientist', 'Statistician', 'Zoologist'],
    'Social Services/Community Development': ['Community Arts Worker', 'Community Development Worker', 'Counsellor', 'Guidance Worker', 'Social Worker', 'Support Worker', 'Youth Worker'],
    'Retail/Hospitality': ['Barista', 'Brewer', 'Butcher', 'Caterer', 'Chef', 'Food Technologist', 'Hotel Manager', 'Publican', 'Restaurant Manager', 'Retail Buyer', 'Retail Manager', 'Sommelier'],
    'Others': ['Armed Forces Officer', 'Diplomat', 'Emergency Services Worker', 'Funeral Director', 'Local Government Officer', 'Member of Parliament (MP)', 'Public Servant', 'Religious Leader', 'Security Guard', 'Socialite', 'Taxi Driver', 'Waiter/Waitress']
}

# %%
job_to_category = {job: category for category, jobs in occupations.items() for job in jobs}

# %%
def map_job_to_category(job):
    return job_to_category.get(job, "Other")

df['job_category'] = df['job'].apply(map_job_to_category)

# %%
df.job_category.value_counts()
# Out:
# job_category
# Other                                    1027514
# Healthcare/Medical                         29104
# Business/Management/Administration         18378
# Research/Science                           13338
# Creative/Artistic                          12323
# Accounting/Finance                          5984
# Legal                                       3771
# Retail/Hospitality                          2892
# Engineering/Technical                       2189
# Social Services/Community Development       1918
# Name: count, dtype: int64

# %%
df[df.job_category == 'Other'].job.unique()
# Out:
# array(['Accounting technician', 'Seismic interpreter',
#        'Programme researcher, broadcasting/film/video',
#        'Insurance risk surveyor', 'Therapist, speech and language',
#        'Energy engineer', 'Call centre manager', 'Associate Professor',
#        'Buyer, retail', 'Early years teacher', 'Petroleum engineer',
#        'IT sales professional', 'Engineer, mining', 'Surveyor, quantity',
#        'Psychologist, counselling', 'Research scientist (maths)',
#        'IT consultant', 'Senior tax professional/tax inspector',
#        'Engineer, civil (contracting)', 'Sports development officer',
#        'Horticultural therapist', 'Sports coach',
#        'Designer, exhibition/display', 'Paediatric nurse',
#        'Research officer, government', 'Interior and spatial designer',
#        'Social research officer, government',
#        'Architectural technologist', 'Programmer, systems',
#        'Local government officer', 'Forensic psychologist',
#        'Diplomatic Services operational officer', 'Quarry manager',
#        'Optician, dispensing', 'Health and safety inspector',
#        'Recycling officer', 'Museum/gallery curator',
#        'Historic buildings inspector/conservation officer',
#        'Product manager', 'Special effects artist', 'Designer, textile',
#        'Volunteer coordinator', 'Therapist, music', 'Systems analyst',
#        'Firefighter', 'Teacher, adult education', 'Architect',
#        'Immigration officer', 'Learning disability nurse',
#        'Analytical chemist', 'General practice doctor', 'Bonds trader',
#        'Surveyor, insurance', 'Emergency planning/management officer',
#        'Civil engineer, contracting', 'Materials engineer',
#        'Medical secretary', 'Surveyor, building control', 'Best boy',
#        'Designer, multimedia', 'Occupational psychologist',
#        'Fisheries officer', 'Dancer', 'Adult nurse',
#        'Technical sales engineer', 'Producer, television/film/video',
#        'Administrator, arts', 'Research officer, political party',
#        'Chief Strategy Officer', 'Investment banker, operational',
#        'Teacher, English as a foreign language', 'Prison officer',
#        'Tax adviser', 'Psychiatric nurse', 'Radiographer, diagnostic',
#        'Engineer, land', 'Education officer, museum', 'Financial planner',
#        'Psychologist, educational', 'Metallurgist', 'Ranger/warden',
#        'Patent attorney', 'Sales promotion account executive',
#        'Geographical information systems officer', 'Biochemist, clinical',
#        'Adult guidance worker', 'Computer games developer',
#        'Sports therapist', 'Engineer, chemical',
#        'Clinical research associate', 'Surveyor, hydrographic',
#        'Surveyor, minerals', 'Financial manager', 'Video editor',
#        'Warehouse manager',
#        'Clinical scientist, histocompatibility and immunogenetics',
#        'Electronics engineer', 'Theatre director', 'Therapist, sports',
#        'Office manager', 'Community arts worker', 'Systems developer',
#        'Engineer, electronics', 'Youth worker', 'Patent examiner',
#        'Accountant, chartered certified',
#        'Museum/gallery exhibitions officer',
#        'Community development worker', 'Commissioning editor',
#        'English as a second language teacher', 'Trade mark attorney',
#        'Accountant, chartered public finance',
#        'Environmental health practitioner', 'Leisure centre manager',
#        'Land/geomatics surveyor', 'Designer, interior/spatial',
#        'Physiological scientist', 'Chemical engineer', 'Immunologist',
#        'Financial risk analyst', 'Garment/textile technologist',
#        'Engineer, structural', 'Advertising account executive',
#        'Chartered loss adjuster', 'Programmer, multimedia',
#        'Surveyor, commercial/residential',
#        'Furniture conservator/restorer', 'Warden/ranger',
#        'Arts development officer', 'Games developer', 'Gaffer',
#        'Podiatrist', 'Psychologist, clinical', 'Arboriculturist',
#        'Lecturer, further education', 'TEFL teacher',
#        'Health service manager', 'Conservator, furniture',
#        'Pharmacist, hospital', 'Librarian, public',
#        'Medical technical officer',
#        'Scientist, clinical (histocompatibility and immunogenetics)',
#        'Counselling psychologist', 'Consulting civil engineer',
#        'Town planner', 'Building services engineer', 'Wellsite geologist',
#        'Soil scientist', 'Scientist, research (life sciences)',
#        'Insurance broker', 'Radio producer', 'Further education lecturer',
#        'Heritage manager', 'Environmental consultant',
#        'Veterinary surgeon', 'Risk analyst',
#        'Designer, television/film set', 'Public house manager',
#        'Records manager', 'Therapist, drama',
#        'Education officer, community', 'Engineer, drilling',
#        'Environmental education officer', 'Agricultural consultant',
#        'Software engineer', 'Advertising account planner',
#        'Restaurant manager', 'Editorial assistant',
#        'Estate manager/land agent', 'Designer, jewellery',
#        'Conservator, museum/gallery', 'Housing manager/officer',
#        'Occupational therapist', 'Agricultural engineer',
#        'Editor, film/video', 'Camera operator', 'Physicist, medical',
#        'Commercial art gallery manager', 'Fish farm manager',
#        'Social researcher', 'Data processing manager',
#        'Visual merchandiser', 'Legal executive', "Nurse, children's",
#        'Marketing executive', 'Management consultant',
#        'Environmental manager', 'Fine artist', 'Quality manager',
#        'Retail banker', 'Scientist, biomedical', 'Optometrist',
#        'Psychotherapist, child', 'Chemist, analytical', 'Archivist',
#        'Engineer, maintenance', 'Curator', 'Legal secretary',
#        'Designer, ceramics/pottery', 'Comptroller', 'Psychotherapist',
#        'Psychologist, forensic', 'Chief Technology Officer',
#        'Food technologist', 'Health physicist',
#        'Psychologist, sport and exercise', 'Economist', 'Water engineer',
#        'Secondary school teacher', 'Clinical embryologist',
#        'Surveyor, planning and development',
#        'Trade union research officer', 'Sub', 'Nurse, mental health',
#        'Public relations officer', 'Site engineer',
#        'Horticulturist, amenity', 'Broadcast journalist',
#        'Sales professional, IT', 'Civil Service fast streamer',
#        'Fitness centre manager', 'Retail merchandiser',
#        'Trading standards officer', 'Intelligence analyst',
#        'Broadcast engineer', 'Engineer, materials',
#        'Engineer, manufacturing systems', 'Loss adjuster, chartered',
#        'Careers adviser', 'Nurse, adult', 'Engineering geologist',
#        'Data scientist', 'Radio broadcast assistant', 'Ship broker',
#        'Graphic designer', 'Health visitor', 'Quantity surveyor',
#        'Scientist, water quality', 'Armed forces technical officer',
#        'Advice worker', 'Special educational needs teacher',
#        'Community education officer', 'Energy manager',
#        'Medical illustrator', 'Customer service manager', 'Retail buyer',
#        'Contracting civil engineer', 'Stage manager',
#        "Politician's assistant", 'Copywriter, advertising',
#        'Occupational hygienist', 'Psychotherapist, dance movement',
#        'Equities trader', 'Engineer, aeronautical',
#        'Teaching laboratory technician',
#        'Government social research officer', 'Teacher, primary school',
#        'Scientist, audiological', 'Lecturer, higher education',
#        'Exhibitions officer, museum/gallery', 'Charity fundraiser',
#        'Ambulance person', 'Psychologist, prison and probation services',
#        'Operational investment banker', 'Therapist, occupational',
#        'Insurance claims handler', 'Armed forces operational officer',
#        'Engineer, petroleum', 'Theatre stage manager',
#        'Nurse, learning disability', 'Set designer',
#        'Sport and exercise psychologist', 'Passenger transport manager',
#        'Waste management officer', 'Mechanical engineer',
#        'Equality and diversity officer', 'Animal nutritionist',
#        'Pension scheme manager', 'Mental health nurse',
#        'Transport planner', 'Engineer, water', 'Chartered accountant',
#        'Television floor manager', 'Brewing technologist',
#        'English as a foreign language teacher', 'Location manager',
#        'Insurance account manager', 'Secretary/administrator',
#        'Public relations account executive', 'Advertising copywriter',
#        'Publishing rights manager', 'Designer, furniture',
#        'Chartered management accountant', 'Multimedia programmer',
#        "Barrister's clerk", 'Careers information officer',
#        'Jewellery designer', 'Geologist, engineering',
#        'Pensions consultant', 'Colour technologist', 'Cytogeneticist',
#        'Aeronautical engineer', 'Clinical cytogeneticist', 'Cabin crew',
#        'Financial adviser', 'Engineer, technical sales',
#        'Embryologist, clinical', 'Retail manager', 'Product designer',
#        'Commercial/residential surveyor', 'Advertising art director',
#        'Hotel manager', 'Operational researcher', 'Copy',
#        'Publishing copy', 'Surveyor, mining',
#        'Manufacturing systems engineer', 'Make', 'Engineer, automotive',
#        'Field seismologist', 'Facilities manager',
#        'Conservation officer, historic buildings', 'Automotive engineer',
#        'Engineer, building services', 'Arts administrator',
#        'Radiographer, therapeutic', 'Accountant, chartered management',
#        'Forensic scientist', 'Land', 'Research scientist (medical)',
#        'Technical author', 'Estate agent', 'Teacher, early years/pre',
#        'Doctor, hospital', 'Mining engineer',
#        'Research scientist (life sciences)', 'Buyer, industrial',
#        'Risk manager', 'Scientist, research (physical sciences)',
#        'Producer, radio', 'Air cabin crew', 'Marine scientist',
#        'Nutritional therapist', 'Production engineer',
#        'Geologist, wellsite', 'Accommodation manager', 'Teacher, music',
#        'Industrial buyer', 'Banker', 'Teacher, secondary school',
#        'Scientist, physiological', 'Health promotion specialist',
#        'Tourism officer', 'IT trainer', 'Hydrologist',
#        'Hydrographic surveyor', 'Lexicographer', 'Ceramics designer',
#        'Research scientist (physical sciences)',
#        'Civil Service administrator', 'Scientist, research (medical)',
#        'Catering manager', 'Control and instrumentation engineer',
#        'Engineer, maintenance (IT)', 'Financial trader',
#        'Building control surveyor', 'Tour manager', 'Chiropractor',
#        'Primary school teacher', 'Travel agency manager',
#        'Network engineer', 'Print production planner',
#        'Medical laboratory scientific officer',
#        'Regulatory affairs officer',
#        'Administrator, charities/voluntary organisations',
#        'Commercial horticulturist', 'Building surveyor',
#        'Sales executive', 'Designer, industrial/product',
#        'Information systems manager', 'Applications developer',
#        'Market researcher', 'Information officer', 'Homeopath',
#        'Educational psychologist', 'Structural engineer',
#        'Hospital pharmacist', 'Community pharmacist',
#        'Therapist, nutritional',
#        'Production designer, theatre/television/film',
#        'Geophysical data processor', 'Clothing/textile technologist',
#        'Merchandiser, retail', 'Clinical psychologist',
#        'Maintenance engineer', 'Restaurant manager, fast food',
#        'Rural practice surveyor', 'Actuary', 'Private music teacher',
#        'Horticultural consultant', 'Administrator, education',
#        'Cartographer', 'Music therapist', 'Designer, fashion/clothing',
#        'Purchasing manager', 'Accountant, chartered',
#        'Audiological scientist', 'Holiday representative',
#        'Television/film/video producer', 'Diagnostic radiographer',
#        'Clinical molecular geneticist', 'Communications engineer',
#        'International aid/development worker',
#        'Engineer, broadcasting (operations)', 'Magazine features editor',
#        'Secretary, company', 'Phytotherapist',
#        'Radiation protection practitioner',
#        'Scientist, product/process development',
#        'Scientific laboratory technician', 'Press sub', 'Farm manager',
#        'Licensed conveyancer', 'Tourist information centre manager',
#        'Broadcast presenter', 'Conservation officer, nature',
#        'Editor, commissioning',
#        'Armed forces logistics/support/administrative officer',
#        'Production assistant, television', 'Drilling engineer',
#        'Furniture designer', 'Clinical biochemist', 'Scientist, marine',
#        'Therapist, art', 'Geneticist, molecular', 'Police officer',
#        'Engineer, manufacturing', 'Presenter, broadcasting',
#        'Designer, graphic', 'Surveyor, rural practice',
#        'Teacher, special educational needs', 'Airline pilot',
#        'Engineer, energy', 'Herbalist', 'Health and safety adviser',
#        'Art gallery manager',
#        'Armed forces training and education officer',
#        'Education administrator', 'Charity officer',
#        'Electrical engineer', 'Professor Emeritus',
#        'Plant breeder/geneticist', 'Water quality scientist',
#        'Museum/gallery conservator', 'Aid worker', 'Biomedical engineer',
#        'Toxicologist', 'Engineer, agricultural',
#        'Therapist, horticultural', 'Art therapist',
#        'Engineer, communications', 'Company secretary',
#        'Claims inspector/assessor'], dtype=object)

# %%
df.drop(columns=['ssn','first', 'last', 'street', 'zip', 'lat', 'long', 'city_pop', 'dob', 'merch_lat', 'merch_long', 'job'], inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1117411 entries, 0 to 1117410
# Data columns (total 13 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   acct_num        1117411 non-null  int64
#  1   trans_num       1117411 non-null  object
#  2   unix_time       1117411 non-null  datetime64[ns]
#  3   category        1117411 non-null  object
#  4   amt             1117411 non-null  float64
#  5   is_fraud        1117411 non-null  int64
#  6   merchant        1117411 non-null  object
#  7   transaction_id  1117411 non-null  int64
#  8   gender          1117411 non-null  object
#  9   city            1117411 non-null  object
#  10  state           1117411 non-null  object
#  11  age             1117411 non-null  int64
#  12  job_category    1117411 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(7)
# memory usage: 110.8+ MB

# %%
df_numeric = df[['amt', 'age']]

plt.figure(figsize=(10, 6))

n_rows = len(df_numeric.columns) // 3 + (len(df_numeric.columns) % 3 > 0)
n_cols = 3

fig, axs = plt.subplots(n_rows, n_cols, figsize=(n_cols*6, n_rows*4))
fig.tight_layout(pad=5.0)

axs = axs.reshape(-1)

for i, col in enumerate(df_numeric.columns):
    bin_width = 2 * (np.percentile(df_numeric[col], 75) - np.percentile(df_numeric[col], 25)) / (len(df_numeric[col]) ** (1/3))
    num_bins = int(np.ceil((df_numeric[col].max() - df_numeric[col].min()) / bin_width))

    sns.histplot(df_numeric[col], ax=axs[i], bins=num_bins, kde=False)
    axs[i].set_title(col, fontsize=14)

for j in range(i+1, n_rows*n_cols):
    axs[j].set_visible(False)

plt.show()

# %%
df.describe(include='all')
# Out:
#             acct_num                         trans_num  \
# count   1.117411e+06                           1117411
# unique           NaN                           1117411
# top              NaN  b45d68c71229562b6fd243d91b97a742
# freq             NaN                                 1
# mean    4.914869e+11                               NaN
# min     2.348758e+09                               NaN
# 25%     2.520855e+11                               NaN
# 50%     4.734608e+11                               NaN
# 75%     7.514274e+11                               NaN
# max     9.993899e+11                               NaN
# std     2.901648e+11                               NaN
#
#                             unix_time       category           amt  \
# count                         1117411        1117411  1.117411e+06
# unique                            NaN             14           NaN
# top                               NaN  personal_care           NaN
# freq                              NaN         300630           NaN
# mean    2022-09-21 13:47:15.183780096            NaN  6.427793e+01
# min               2022-06-01 00:00:08            NaN  1.000000e+00
# 25%        2022-07-24 08:12:15.500000            NaN  8.200000e+00
# 50%               2022-09-20 11:15:25            NaN  3.315000e+01
# 75%               2022-11-26 10:47:39            NaN  7.636000e+01
# max               2022-12-31 12:59:42            NaN  2.805851e+04
# std                               NaN            NaN  1.862175e+02
#
#             is_fraud     merchant  transaction_id   gender      city    state  \
# count   1.117411e+06      1117411    1.117411e+06  1117411   1117411  1117411
# unique           NaN        16759             NaN        2       722       51
# top              NaN  Johnson LLC             NaN        F  Brooklyn       CA
# freq             NaN         1807             NaN   573517     17433   132575
# mean    1.493631e-03          NaN    6.802466e+01      NaN       NaN      NaN
# min     0.000000e+00          NaN    0.000000e+00      NaN       NaN      NaN
# 25%     0.000000e+00          NaN    4.300000e+01      NaN       NaN      NaN
# 50%     0.000000e+00          NaN    6.700000e+01      NaN       NaN      NaN
# 75%     0.000000e+00          NaN    1.030000e+02      NaN       NaN      NaN
# max     1.000000e+00          NaN    1.300000e+02      NaN       NaN      NaN
# std     3.861867e-02          NaN    3.714663e+01      NaN       NaN      NaN
#
#                  age job_category
# count   1.117411e+06      1117411
# unique           NaN           10
# top              NaN        Other
# freq             NaN      1027514
# mean    4.554020e+01          NaN
# min     1.600000e+01          NaN
# 25%     3.100000e+01          NaN
# 50%     4.300000e+01          NaN
# 75%     5.700000e+01          NaN
# max     9.600000e+01          NaN
# std     1.752612e+01          NaN

# %%
sns.boxplot(y=df[df['amt'] != -1]['amt'])
plt.title('amt')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

# Create a boxplot
sns.boxplot(data=df, x='is_fraud', y='amt')

# Add labels and title
plt.xlabel('Is Fraud')
plt.ylabel('Amount')
plt.title('Boxplot of Amount by Fraud Status')

plt.show()

# %%
df_numeric = df.select_dtypes(include=['float64', 'int64'])

corr_matrix = df_numeric.corr()

plt.figure(figsize=(15, 10))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5, cbar_kws={"shrink": .5})
plt.title('Mapa de Correlación de Variables Numéricas')
plt.show()

# %%
target = 'is_fraud'
sns.countplot(data=df, x=target, order=df[target].value_counts().index)
plt.title(f'{target} Distribution')
plt.xticks(rotation=90)

# %%
df.info()

# %%
sns.set_style("whitegrid")

sns.countplot(data=df, x='category', order=df['category'].value_counts().index, palette="muted")
plt.title(f'{col} Distribution')
plt.xticks(rotation=90)

plt.show()

# %%
sns.set_style("whitegrid")

sns.countplot(data=df, x='merchant', order=df['merchant'].value_counts().index, palette="muted")
plt.title(f'{col} Distribution')
plt.xticks(rotation=90)

# %%
sns.set_style("whitegrid")

sns.countplot(data=df, x='city', order=df['city'].value_counts().index, palette="muted")
plt.title('city Distribution')
plt.xticks(rotation=90)

# %%
sns.set_style("whitegrid")

sns.countplot(data=df, x='gender', order=df['gender'].value_counts().index, palette="muted")
plt.title('gender Distribution')
plt.xticks(rotation=90)

# %%
sns.set_style("whitegrid")

sns.countplot(data=df, x='state', order=df['state'].value_counts().index, palette="muted")
plt.title('state Distribution')
plt.xticks(rotation=90)

# %%
sns.set_style("whitegrid")

sns.countplot(data=df, x='job', order=df['job'].value_counts().index, palette="muted")
plt.title('job Distribution')
plt.xticks(rotation=90)
